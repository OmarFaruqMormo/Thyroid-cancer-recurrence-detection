# %% [markdown]
# <a href="https://colab.research.google.com/github/OmarFaruqMormo/Thyroid-cancer-recurrence-detection/blob/main/Thyroid_Cancer_Recurrence.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # **Thyroid Cancer Recurrence Dataset**
#
# Description: A dataset containing clinical, demographic, and diagnostic information to predict the likelihood of recurrence in thyroid cancer patients. It includes features like age, gender, tumor size, lymph node status, and treatment details.

# %%
data = pd.read_csv("/content/drive/MyDrive/Etchis/Thyroid_Diff.csv")

# %%
# Viewing the first 5 data
data.head()
# Out:
#    Age Gender Smoking Hx Smoking Hx Radiothreapy Thyroid Function  \
# 0   27      F      No         No              No        Euthyroid
# 1   34      F      No        Yes              No        Euthyroid
# 2   30      F      No         No              No        Euthyroid
# 3   62      F      No         No              No        Euthyroid
# 4   62      F      No         No              No        Euthyroid
#
#           Physical Examination Adenopathy       Pathology     Focality Risk  \
# 0   Single nodular goiter-left         No  Micropapillary    Uni-Focal  Low
# 1          Multinodular goiter         No  Micropapillary    Uni-Focal  Low
# 2  Single nodular goiter-right         No  Micropapillary    Uni-Focal  Low
# 3  Single nodular goiter-right         No  Micropapillary    Uni-Focal  Low
# 4          Multinodular goiter         No  Micropapillary  Multi-Focal  Low
#
#      T   N   M Stage       Response Recurred
# 0  T1a  N0  M0     I  Indeterminate       No
# ...

# %%
# Viewing the last 5 data
data.tail()
# Out:
#      Age Gender Smoking Hx Smoking Hx Radiothreapy          Thyroid Function  \
# 378   72      M     Yes        Yes             Yes                 Euthyroid
# 379   81      M     Yes         No             Yes                 Euthyroid
# 380   72      M     Yes        Yes              No                 Euthyroid
# 381   61      M     Yes        Yes             Yes  Clinical Hyperthyroidism
# 382   67      M     Yes         No              No                 Euthyroid
#
#             Physical Examination Adenopathy     Pathology     Focality  Risk  \
# 378  Single nodular goiter-right      Right     Papillary    Uni-Focal  High
# 379          Multinodular goiter  Extensive     Papillary  Multi-Focal  High
# 380          Multinodular goiter  Bilateral     Papillary  Multi-Focal  High
# 381          Multinodular goiter  Extensive  Hurthel cell  Multi-Focal  High
# 382          Multinodular goiter  Bilateral     Papillary  Multi-Focal  High
#
# ...

# %%
# Data info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 383 entries, 0 to 382
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Age                   383 non-null    int64
#  1   Gender                383 non-null    object
#  2   Smoking               383 non-null    object
#  3   Hx Smoking            383 non-null    object
#  4   Hx Radiothreapy       383 non-null    object
#  5   Thyroid Function      383 non-null    object
#  6   Physical Examination  383 non-null    object
#  7   Adenopathy            383 non-null    object
#  8   Pathology             383 non-null    object
#  9   Focality              383 non-null    object
#  10  Risk                  383 non-null    object
#  11  T                     383 non-null    object
#  12  N                     383 non-null    object
#  13  M                     383 non-null    object
#  14  Stage                 383 non-null    object
# ...

# %%
# Rows and columns
data.shape
# Out:
# (383, 17)

# %%
# Data type
data.dtypes
# Out:
# Age                      int64
# Gender                  object
# Smoking                 object
# Hx Smoking              object
# Hx Radiothreapy         object
# Thyroid Function        object
# Physical Examination    object
# Adenopathy              object
# Pathology               object
# Focality                object
# Risk                    object
# T                       object
# N                       object
# M                       object
# Stage                   object
# Response                object
# Recurred                object
# dtype: object

# %% [markdown]
# # **Data Visualization**

# %% [markdown]
# 📊 To understand the underlying patterns and relationships in the dataset, multiple visualization techniques were applied using Matplotlib and Seaborn. These visual tools helped uncover important insights from both categorical and numerical variables.
#
# 📌 Key Visualizations:
# 🟦 Gender Distribution (Pie Chart):
# Visualized the proportion of male and female patients to understand gender balance.
#
# 📊 Grouped Bar Charts:
#
# 🔹 Hx Radiotherapy vs Recurrence: Showed how recurrence is distributed among patients with or without a history of radiotherapy.
#
# 🔹 Adenopathy vs Risk: Displayed how risk levels vary with the presence or absence of adenopathy.
#
# 🔹 Pathology vs Recurrence / Stage vs Risk / Focality vs Recurrence: Highlighted how recurrence or risk levels vary across different pathology types, stages, and focality levels.
#
# 🔹 Response vs Recurrence: Illustrated how different treatment responses relate to recurrence rates.
#
# 🔢 Categorical-to-Numeric Conversion:
# Variables like 'T', 'N', 'M', and 'Stage' were encoded into numeric values to enable quantitative analysis and correlation computation.
#
# 🧊 Correlation Heatmaps:
#
# 🌡️ TNM Staging Correlation: Measured how the T, N, and M variables relate to each other.
#
# 🌡️ Numerical Features Correlation: Showed interdependence between Age, T, N, M, and Stage to identify strong or weak correlations.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Age vs Risk - Boxplot
plt.figure(figsize=(8, 5))
sns.boxplot(x='Risk', y='Age', data=data)
plt.title('Age vs Risk')
plt.xlabel('Level of Risk')
plt.ylabel('Age')


plt.show()

# %%
# Gender Distribution
# Set the size of the figure to 6x6 inches
plt.figure(figsize=(6,6))

# Create a pie chart from the value counts of the 'Gender' column
# 'autopct' formats the percentages shown on the chart
# 'colors' defines custom colors for the slices
data['Gender'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%',
    colors=['skyblue', 'salmon']
)

# Set the title of the pie chart
plt.title('Gender Distribution')

# Remove the y-axis label (not needed for pie charts)
plt.ylabel('')

# Display the pie chart
plt.show()

# %%
# Hx Radiotherapy vs Recurrence - Grouped Bar Chart

plt.figure(figsize=(8,6))

# Create a grouped bar chart using seaborn
# 'x' specifies the primary category (Hx Radiotherapy)
# 'data' is the DataFrame to use
sns.countplot(x='Hx Radiothreapy', hue='Recurred', data=data, palette='coolwarm')

# Add a title to the chart
plt.title('Hx Radiotherapy vs Recurrence')

# Show the plot
plt.show()

# %%
#Adenopathy vs Risk - Stacked Bar Chart

plt.figure(figsize=(8,6))

# Create a count plot (bar chart) using seaborn
# 'x' sets the main category to group by (Adenopathy)
# 'data' is the DataFrame being used
sns.countplot(x='Adenopathy', hue='Risk', data=data, palette='Set2')

# Set the title of the plot
plt.title('Adenopathy vs Risk')

# Display the final plot
plt.show()

# %%
# Pathology vs Recurrence - Bar Chart

plt.figure(figsize=(8,6))

# Create a grouped bar chart using seaborn
# 'x' is the categorical feature (Pathology)
# 'data' is the DataFrame we're working with
sns.countplot(x='Pathology', hue='Recurred', data=data, palette='muted')

# Add a title to the plot
plt.title('Pathology vs Recurrence')

# Rotate x-axis labels by 45 degrees for better readability
plt.xticks(rotation=45)

# Display the final plot
plt.show()

# %%
# 6. Focality vs Recurrence - Grouped Bar Chart (Seaborn countplot by default creates grouped bars)

# Set the size of the figure (8 inches wide by 6 inches tall)
plt.figure(figsize=(8,6))

# Create a grouped bar chart using seaborn
# 'x' is the main category: Focality
# 'hue' splits the bars by the 'Recurred' status
# 'data' is your DataFrame
# 'palette' sets the color scheme to 'coolwarm'
sns.countplot(x='Focality', hue='Recurred', data=data, palette='coolwarm')

# Add a title to the chart
plt.title('Focality vs Recurrence')

# Display the plot
plt.show()

# %%
import re  # For using regular expressions
import matplotlib.pyplot as plt  # For plotting
import seaborn as sns  # For visualizing with heatmap

# Function to extract the numeric part from strings like 'T1a', 'T2', etc.
def extract_numeric_value(column):
    # Use regex to remove all non-digit characters and convert to int
    return column.apply(lambda x: int(re.sub(r'\D', '', str(x))))

# Apply the extraction function to the 'T', 'N', and 'M' columns in the DataFrame
data['T'] = extract_numeric_value(data['T'])
data['N'] = extract_numeric_value(data['N'])
data['M'] = extract_numeric_value(data['M'])

# Compute correlation between T, N, and M values
tnm_data = data[['T', 'N', 'M']].corr()

# Plotting the correlation heatmap
plt.figure(figsize=(6,5))  # Set figure size
sns.heatmap(
    tnm_data,               # Correlation matrix data
    annot=True,             # Display correlation values on the heatmap
    cmap='coolwarm',        # Use a cool-to-warm color scheme
    fmt='.2f',              # Format annotation to 2 decimal places
    linewidths=0.5          # Add space between heatmap cells
)
plt.title('TNM Staging Correlation Heatmap')  # Title of the heatmap
plt.show()  # Display the heatmap

# %%
# Stage vs Risk - Bar Chart

plt.figure(figsize=(8,6))

# Create a grouped bar chart using seaborn
# 'x' is the main categorical variable (Stage)
# 'data' is the DataFrame containing your data
sns.countplot(x='Stage', hue='Risk', data=data, palette='viridis')

# Add a title to the chart
plt.title('Stage vs Risk')

# Display the bar chart
plt.show()

# %%
# Response vs Recurrence - Grouped Bar Chart

plt.figure(figsize=(8,6))

# Create a grouped bar chart using seaborn's countplot
# 'x' is the category (Response)
# 'data' is your DataFrame
sns.countplot(x='Response', hue='Recurred', data=data, palette='magma')

# Set the title of the chart
plt.title('Response vs Recurrence')

# Show the plot
plt.show()

# %%
# Function to convert selected categorical columns into numeric codes
def convert_to_numeric(df, columns):
    for col in columns:
        df[col] = df[col].astype('category').cat.codes
    return df

# Convert the categorical columns 'T', 'N', 'M', and 'Stage' into numeric values
df = convert_to_numeric(data, ['T', 'N', 'M', 'Stage'])

# Select numeric columns for correlation analysis
numerical_cols = df[['Age', 'T', 'N', 'M', 'Stage']]  # Make sure all are now numeric

# Set the figure size for the heatmap
plt.figure(figsize=(8,6))

# Plot a heatmap of correlations among the selected numerical features
sns.heatmap(
    numerical_cols.corr(),  # Compute correlation matrix
    annot=True,             # Show correlation values inside the heatmap cells
    cmap='YlGnBu',          # Set the color map (Yellow-Green-Blue)
    fmt='.2f'               # Format the annotation to 2 decimal places
)

# Add a title to the heatmap
plt.title('Correlation Heatmap of Numerical Features')

# Display the heatmap
plt.show()

# %% [markdown]
# # **Predictive modeling**

# %% [markdown]
# Logistic Regression: 92.17%
# Random Forest: 98.26%
# Gradient Boosting: 96.52%
# Support Vector Classifier: 80.00%
# Decision Tree: 93.04%
# K-Nearest Neighbors: 86.96%

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
# Label Encoding for categorical variables
#label_encoder = LabelEncoder()

# %%
# Apply label encoding to all non-numeric columns
#df['Gender'] = label_encoder.fit_transform(df['Gender'])
#df['Hx Radiothreapy'] = label_encoder.fit_transform(df['Hx Radiothreapy'])
#df['Adenopathy'] = label_encoder.fit_transform(df['Adenopathy'])
#df['Pathology'] = label_encoder.fit_transform(df['Pathology'])
#df['Focality'] = label_encoder.fit_transform(df['Focality'])
#df['Risk'] = label_encoder.fit_transform(df['Risk'])
#df['Response'] = label_encoder.fit_transform(df['Response'])
#df['Recurred'] = label_encoder.fit_transform(df['Recurred'])  # Target variable

# %%
from sklearn.preprocessing import LabelEncoder

# Encode all object-type columns
label_encoders = {}
for col in df.columns:
    if df[col].dtype == 'object':
        le = LabelEncoder()
        df[col] = le.fit_transform(df[col])
        label_encoders[col] = le  # Optional: store encoder

# %%
# Split the data into features (X) and target (y)
X = df.drop('Recurred', axis=1)  # Features
y = df['Recurred']  # Target

# %%
# Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Initialize the models
models = {
    "Logistic Regression": LogisticRegression(),
    "Random Forest": RandomForestClassifier(),
    "Gradient Boosting": GradientBoostingClassifier(),
    "Support Vector Classifier": SVC(),
    "Decision Tree": DecisionTreeClassifier(),
    "K-Nearest Neighbors": KNeighborsClassifier()
}

# %%
from sklearn.metrics import roc_auc_score, roc_curve

# Train models, evaluate accuracy, confusion matrix, and plot ROC curve
results = {}

for name, model in models.items():
    print(f"\n🔍 Evaluating Model: {name}")

    # Fit the model
    model.fit(X_train, y_train)

    # Predict labels and probabilities
    y_pred = model.predict(X_test)

    # Try to get prediction probabilities for ROC curve
    try:
        y_prob = model.predict_proba(X_test)[:, 1]  # Probability of class 1
    except AttributeError:
        y_prob = model.decision_function(X_test)   # For models like SVM
        y_prob = (y_prob - y_prob.min()) / (y_prob.max() - y_prob.min())  # Normalize for ROC

    # Calculate metrics
    accuracy = accuracy_score(y_test, y_pred) * 100
    auc_score = roc_auc_score(y_test, y_prob)
    results[name] = {"Accuracy": accuracy, "AUC": auc_score}

    # Print metrics
    print(f"✅ Accuracy: {accuracy:.2f}%")
    print(f"🏅 AUC Score: {auc_score:.2f}")

    # Plot confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
                xticklabels=['No Recurrence', 'Recurrence'],
                yticklabels=['No Recurrence', 'Recurrence'])
    plt.title(f'Confusion Matrix: {name}')
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.tight_layout()
    plt.show()

    # Plot ROC curve
    fpr, tpr, _ = roc_curve(y_test, y_prob)
    plt.figure(figsize=(6, 5))
    plt.plot(fpr, tpr, label=f'{name} (AUC = {auc_score:.2f})')
    plt.plot([0, 1], [0, 1], 'k--', lw=1)
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curve: {name}')
    plt.legend(loc='lower right')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    print('-' * 50)
# Out:
# 🔍 Evaluating Model: Logistic Regression
# ✅ Accuracy: 92.17%
# 🏅 AUC Score: 0.95
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# --------------------------------------------------
#
# 🔍 Evaluating Model: Random Forest
# ✅ Accuracy: 98.26%
# 🏅 AUC Score: 0.99
# --------------------------------------------------
#
# 🔍 Evaluating Model: Gradient Boosting
# ✅ Accuracy: 96.52%
# 🏅 AUC Score: 0.99
# --------------------------------------------------
#
# 🔍 Evaluating Model: Support Vector Classifier
# ...

# %%
# Print the accuracy results for each model
print("Model Accuracy Results (in percentage):")
for model, accuracy in results.items():
    print(f"{model}: {accuracy['Accuracy']:.2f}%") # Access the 'Accuracy' key within the accuracy dictionary
# Out:
# Model Accuracy Results (in percentage):
# Logistic Regression: 92.17%
# Random Forest: 98.26%
# Gradient Boosting: 96.52%
# Support Vector Classifier: 80.00%
# Decision Tree: 94.78%
# K-Nearest Neighbors: 86.96%

# %% [markdown]
# # **Feature Importance of each model.**

# %%
import pandas as pd
import numpy as np

# Assuming you have your models dictionary like this:
# models = {
#     'Random Forest': RandomForestClassifier(),
#     'Gradient Boosting': GradientBoostingClassifier(),
#     'AdaBoost': AdaBoostClassifier(),
#     'Decision Tree': DecisionTreeClassifier(),
#     'SVC': SVC(probability=True),
#     'KNN': KNeighborsClassifier()
# }

feature_names = X_train.columns.tolist()
importance_table = pd.DataFrame({'Feature': feature_names})

for name, model in models.items():
    try:
        model.fit(X_train, y_train)

        if hasattr(model, 'feature_importances_'):
            importances = model.feature_importances_
        elif hasattr(model, 'coef_'):
            importances = np.abs(model.coef_[0])
        else:
            importances = np.zeros(len(feature_names))  # fallback for unsupported models

        importance_table[name] = importances

    except Exception as e:
        print(f"❌ Failed to compute importance for {name}: {e}")
        importance_table[name] = np.nan  # handle failure gracefully

# Optional: Round for readability
importance_table = importance_table.round(3)

# Display the final table
print(importance_table)

# Save to CSV (optional)
importance_table.to_csv("feature_importance_table.csv", index=False)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#                  Feature  Logistic Regression  Random Forest  \
# 0                    Age                0.008          0.077
# 1                 Gender                0.798          0.023
# 2                Smoking                0.160          0.010
# 3             Hx Smoking                0.841          0.003
# 4        Hx Radiothreapy                0.026          0.001
# 5       Thyroid Function                0.158          0.014
# ...

# %% [markdown]
# # **Model Comparison Dashboard**

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# Initialize a list to hold all metric records
comparison_results = []

for name, model in models.items():
    print(f"\n🔍 Evaluating Model: {name}")

    # Train the model
    model.fit(X_train, y_train)

    # Predict class and probability
    y_pred = model.predict(X_test)

    try:
        y_prob = model.predict_proba(X_test)[:, 1]
    except AttributeError:
        y_prob = model.decision_function(X_test)
        y_prob = (y_prob - y_prob.min()) / (y_prob.max() - y_prob.min())  # Normalize

    # Metrics
    accuracy = accuracy_score(y_test, y_pred) * 100
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    auc = roc_auc_score(y_test, y_prob)

    # Store results in list
    comparison_results.append({
        'Model': name,
        'Accuracy (%)': round(accuracy, 2),
        'Precision': round(precision, 2),
        'Recall': round(recall, 2),
        'F1 Score': round(f1, 2),
        'AUC Score': round(auc, 2)
    })

# Convert to DataFrame for display
results_df = pd.DataFrame(comparison_results)
results_df = results_df.sort_values(by='Accuracy (%)', ascending=False).reset_index(drop=True)

# Display
print("\n📊 Model Comparison Dashboard:\n")
print(results_df)

# Optional: visualize with barplot
plt.figure(figsize=(10, 6))
sns.barplot(x='Accuracy (%)', y='Model', data=results_df, palette='Spectral')
plt.title('Model Accuracy Comparison')
plt.xlabel('Accuracy (%)')
plt.ylabel('Model')
plt.tight_layout()
plt.show()
# Out:
# 🔍 Evaluating Model: Logistic Regression
#
# 🔍 Evaluating Model: Random Forest
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 🔍 Evaluating Model: Gradient Boosting
#
# 🔍 Evaluating Model: Support Vector Classifier
#
# 🔍 Evaluating Model: Decision Tree
#
# 🔍 Evaluating Model: K-Nearest Neighbors
#
# 📊 Model Comparison Dashboard:
#
#                        Model  Accuracy (%)  Precision  Recall  F1 Score  \
# 0              Random Forest         98.26       0.97    0.97      0.97
# ...

# %% [markdown]
# # **SMOTE**

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, roc_auc_score, roc_curve
from imblearn.over_sampling import SMOTE
import matplotlib.pyplot as plt
import seaborn as sns

# Apply SMOTE to training data
smote = SMOTE(random_state=42)
X_train_res, y_train_res = smote.fit_resample(X_train, y_train)

# Train models, evaluate accuracy, confusion matrix, and plot ROC curve
results = {}

for name, model in models.items():
    print(f"\n🔍 Evaluating Model: {name}")

    # Fit the model using resampled training data
    model.fit(X_train_res, y_train_res)

    # Predict labels and probabilities
    y_pred = model.predict(X_test)

    # Try to get prediction probabilities for ROC curve
    try:
        y_prob = model.predict_proba(X_test)[:, 1]  # Probability of class 1
    except AttributeError:
        y_prob = model.decision_function(X_test)   # For models like SVM
        y_prob = (y_prob - y_prob.min()) / (y_prob.max() - y_prob.min())  # Normalize for ROC

    # Calculate metrics
    accuracy = accuracy_score(y_test, y_pred) * 100
    auc_score = roc_auc_score(y_test, y_prob)
    results[name] = {"Accuracy": accuracy, "AUC": auc_score}

    # Print metrics
    print(f"✅ Accuracy: {accuracy:.2f}%")
    print(f"🏅 AUC Score: {auc_score:.2f}")

    # Plot confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
                xticklabels=['No Recurrence', 'Recurrence'],
                yticklabels=['No Recurrence', 'Recurrence'])
    plt.title(f'Confusion Matrix: {name}')
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.tight_layout()
    plt.show()

    # Plot ROC curve
    fpr, tpr, _ = roc_curve(y_test, y_prob)
    plt.figure(figsize=(6, 5))
    plt.plot(fpr, tpr, label=f'{name} (AUC = {auc_score:.2f})')
    plt.plot([0, 1], [0, 1], 'k--', lw=1)
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curve: {name}')
    plt.legend(loc='lower right')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    print('-' * 50)
# Out:
# 🔍 Evaluating Model: Logistic Regression
# ✅ Accuracy: 92.21%
# 🏅 AUC Score: 0.93
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# --------------------------------------------------
#
# 🔍 Evaluating Model: Random Forest
# ✅ Accuracy: 97.40%
# 🏅 AUC Score: 1.00
# --------------------------------------------------
#
# 🔍 Evaluating Model: Gradient Boosting
# ✅ Accuracy: 96.10%
# 🏅 AUC Score: 1.00
# --------------------------------------------------
#
# 🔍 Evaluating Model: Support Vector Classifier
# ...

# %% [markdown]
# # **Hyper Parameter Tuning: GridSearchCV**

# %%
from sklearn.model_selection import GridSearchCV

# Define hyperparameter grids for each model
param_grids = {
    "Logistic Regression": {
        'C': [0.01, 0.1, 1, 10],
        'solver': ['liblinear']
    },
    "Random Forest": {
        'n_estimators': [100, 200],
        'max_depth': [None, 10, 20],
        'min_samples_split': [2, 5]
    },
    "Gradient Boosting": {
        'n_estimators': [100, 200],
        'learning_rate': [0.01, 0.1, 0.2],
        'max_depth': [3, 5]
    },
    "Support Vector Classifier": {
        'C': [0.1, 1, 10],
        'kernel': ['linear', 'rbf']
    },
    "Decision Tree": {
        'max_depth': [None, 10, 20],
        'min_samples_split': [2, 5, 10]
    },
    "K-Nearest Neighbors": {
        'n_neighbors': [3, 5, 7],
        'weights': ['uniform', 'distance']
    }
}

# %%
from sklearn.model_selection import GridSearchCV

results = {}

for name, model in models.items():
    print(f"\n🔍 Tuning & Evaluating Model: {name}")

    # Get hyperparameter grid
    param_grid = param_grids.get(name, {})

    # GridSearchCV
    grid = GridSearchCV(model, param_grid, cv=5, scoring='roc_auc', n_jobs=-1)
    grid.fit(X_train_res, y_train_res)

    # Best estimator
    best_model = grid.best_estimator_
    print(f"📌 Best Params: {grid.best_params_}")

    # Evaluate the best model
    y_pred = best_model.predict(X_test)

    # Probabilities for ROC/AUC
    try:
        y_prob = best_model.predict_proba(X_test)[:, 1]
    except AttributeError:
        y_prob = best_model.decision_function(X_test)
        y_prob = (y_prob - y_prob.min()) / (y_prob.max() - y_prob.min())

    # Accuracy and AUC
    accuracy = accuracy_score(y_test, y_pred) * 100
    auc_score = roc_auc_score(y_test, y_prob)
    results[name] = {
        "Accuracy": accuracy,
        "AUC": auc_score,
        "Best Params": grid.best_params_
    }

    print(f"✅ Accuracy: {accuracy:.2f}%")
    print(f"🏅 AUC Score: {auc_score:.2f}")

    # Confusion Matrix
    cm = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
                xticklabels=['No Recurrence', 'Recurrence'],
                yticklabels=['No Recurrence', 'Recurrence'])
    plt.title(f'Confusion Matrix: {name}')
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.tight_layout()
    plt.show()

    # ROC Curve
    fpr, tpr, _ = roc_curve(y_test, y_prob)
    plt.figure(figsize=(6, 5))
    plt.plot(fpr, tpr, label=f'{name} (AUC = {auc_score:.2f})')
    plt.plot([0, 1], [0, 1], 'k--', lw=1)
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curve: {name}')
    plt.legend(loc='lower right')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    print('-' * 50)
# Out:
# 🔍 Tuning & Evaluating Model: Logistic Regression
# 📌 Best Params: {'C': 0.1, 'solver': 'liblinear'}
# ✅ Accuracy: 93.51%
# 🏅 AUC Score: 0.94
# --------------------------------------------------
#
# 🔍 Tuning & Evaluating Model: Random Forest
# 📌 Best Params: {'max_depth': 20, 'min_samples_split': 2, 'n_estimators': 100}
# ✅ Accuracy: 97.40%
# 🏅 AUC Score: 1.00
# --------------------------------------------------
#
# 🔍 Tuning & Evaluating Model: Gradient Boosting
# 📌 Best Params: {'learning_rate': 0.2, 'max_depth': 3, 'n_estimators': 200}
# ✅ Accuracy: 96.10%
# 🏅 AUC Score: 1.00
# --------------------------------------------------
#
# 🔍 Tuning & Evaluating Model: Support Vector Classifier
# 📌 Best Params: {'C': 0.1, 'kernel': 'linear'}
# ✅ Accuracy: 92.21%
# 🏅 AUC Score: 0.93
# --------------------------------------------------
#
# 🔍 Tuning & Evaluating Model: Decision Tree
# 📌 Best Params: {'max_depth': None, 'min_samples_split': 10}
# ✅ Accuracy: 94.81%
# 🏅 AUC Score: 0.95
# ...

# %%
import warnings
warnings.filterwarnings('ignore')  # Suppress warnings

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score
)
from sklearn.model_selection import GridSearchCV
from imblearn.over_sampling import SMOTE
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Assuming X_train, y_train, X_test, y_test are defined

# Apply SMOTE to handle class imbalance
smote = SMOTE(random_state=42)
X_train_res, y_train_res = smote.fit_resample(X_train, y_train)

# Define models
models = {
    "Logistic Regression": LogisticRegression(),
    "Random Forest": RandomForestClassifier(),
    "Gradient Boosting": GradientBoostingClassifier(),
    "Support Vector Classifier": SVC(probability=True),
    "Decision Tree": DecisionTreeClassifier(),
    "K-Nearest Neighbors": KNeighborsClassifier()
}

# Define hyperparameter grids
param_grids = {
    "Logistic Regression": {'C': [0.01, 0.1, 1, 10], 'solver': ['liblinear']},
    "Random Forest": {'n_estimators': [100, 200], 'max_depth': [None, 10, 20], 'min_samples_split': [2, 5]},
    "Gradient Boosting": {'n_estimators': [100, 200], 'learning_rate': [0.01, 0.1, 0.2], 'max_depth': [3, 5]},
    "Support Vector Classifier": {'C': [0.1, 1, 10], 'kernel': ['linear', 'rbf']},
    "Decision Tree": {'max_depth': [None, 10, 20], 'min_samples_split': [2, 5, 10]},
    "K-Nearest Neighbors": {'n_neighbors': [3, 5, 7], 'weights': ['uniform', 'distance']}
}

# Final results for dashboard
comparison_results = []

for name, model in models.items():
    param_grid = param_grids.get(name, {})
    grid = GridSearchCV(model, param_grid, cv=5, scoring='roc_auc', n_jobs=-1)
    grid.fit(X_train_res, y_train_res)
    best_model = grid.best_estimator_

    # Predict
    y_pred = best_model.predict(X_test)
    try:
        y_prob = best_model.predict_proba(X_test)[:, 1]
    except AttributeError:
        y_prob = best_model.decision_function(X_test)
        y_prob = (y_prob - y_prob.min()) / (y_prob.max() - y_prob.min())

    # Metrics
    accuracy = accuracy_score(y_test, y_pred) * 100
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    auc = roc_auc_score(y_test, y_prob)

    # Save to results list
    comparison_results.append({
        'Model': name,
        'Accuracy (%)': round(accuracy, 2),
        'Precision': round(precision, 2),
        'Recall': round(recall, 2),
        'F1 Score': round(f1, 2),
        'AUC Score': round(auc, 2)
    })

# Create DataFrame and sort by Accuracy
results_df = pd.DataFrame(comparison_results)
results_df = results_df.sort_values(by='Accuracy (%)', ascending=False).reset_index(drop=True)

# Print dashboard table
print("\n📊 Model Comparison Dashboard:\n")
print(results_df)

# Bar Chart for Accuracy
plt.figure(figsize=(10, 6))
sns.barplot(x='Accuracy (%)', y='Model', data=results_df, palette='viridis')
plt.title('Model Accuracy Comparison')
plt.xlabel('Accuracy (%)')
plt.ylabel('Model')
plt.tight_layout()
plt.savefig('accuracy_comparison.png')
# Out:
# 📊 Model Comparison Dashboard:
#
#                        Model  Accuracy (%)  Precision  Recall  F1 Score  \
# 0              Random Forest         97.40       0.95    0.95      0.95
# 1          Gradient Boosting         96.10       0.90    0.95      0.92
# 2              Decision Tree         94.81       0.89    0.89      0.89
# 3        Logistic Regression         93.51       0.94    0.79      0.86
# 4  Support Vector Classifier         92.21       0.88    0.79      0.83
# 5        K-Nearest Neighbors         88.31       0.86    0.63      0.73
#
#    AUC Score
# 0       1.00
# 1       1.00
# 2       0.95
# 3       0.94
# 4       0.93
# 5       0.89
